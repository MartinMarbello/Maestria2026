# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinMarbello/Maestria2026/blob/main/Sustentaciones_Martin_Marbello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Formato para Trabajar en Colab 2025**
# # **Escribe el Nombre del Curso**
# ## **Escribe tu nombre completo**
# > Email: martin.marbello12@gmail.com
#
# > Celular: 3136900268
#
# > T00064762

# %% [markdown]
# # **Librerias para Trabar en R**

# %%
# @title **Librerias para Trabar en R**
import rpy2.rinterface_lib.callbacks as rcb
import logging

# Desactivar warnings de R en Python
rcb.logger.setLevel(logging.ERROR)  # Solo muestra errores, no warnings
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import sys
# Instala rpy2 si no está instalado
if 'rpy2' not in sys.modules:
    # !pip install rpy2

# %%
# @title Recargando Librerias para Trabajar en R
import rpy2.rinterface_lib.callbacks as rcb
import logging

# Desactivar warnings de R en Python
rcb.logger.setLevel(logging.ERROR)  # Solo muestra errores, no warnings
# %load_ext rpy2.ipython

# %% [markdown]
# <a name="inicio"></a>
#
#
# ## **1.** [Simulación de lanzar una moneda al aire y observar la cara de la moneda que mira hacia arriba al caer.](#T1)
# ## **2.** [Experimento Aleatorio - Lanzamiento de un dado (6 caras)](#T2)
#
# ## **3.** [Experimento: Lanzamiento de una moneda](#T3)
#
# ## **4.** [Ejemplo 1: Lanzamiento de un dado justo usando R](#T4)
#
# ## **5.** [Ejemplo: Preferencias de helado usando R](#T5)
#
# ## **6.** [Probabilidad clasica](#T6)
#
# ## **7.** [Ejemplo 1: Estimación de la probabilidad de obtener cara en una moneda (posiblemente sesgada)](#T7)
#
#
# ## **8.** [Técnicas de Conteo - Formación de Números](#T8)
#
# ## **9.** [](#T9)
#
#
# ## **10.** [](#T10)
#
# ## **11.** [](#T11)
#
# ## **12.** [](#T12)
#
# ## **13.** [](#T13)
#
# ## **14.** [](#T14)
#
# ## **15.** [](#T15)
#
# ## **16.** [](#T16)
#
# ## **17.** [](#T17)
#
#
# ## **18.** [](#T18)
#
# ## **19.** [](#T19)
#
#
# ## **20.** [](#T20)
#
# ## **21.** [](#T21)
#
# ## **22.** [](#T22)
#
# ## **23.** [](#T23)
#
# ## **24.** [](#T24)
#
# ## **25.** [](#T25)
#
# ## **26.** [](#T26)
#
# ## **27.** [](#T27)
#
#
# ## **28.** [](#T28)
#
# ## **29.** [](#T29)
#
#
# ## **30.** [](#T30)
#
# ## **31.** [](#T31)

# %% [markdown]
# [ULTIMO](#ULTIMO)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# ## **1. Simulación de lanzar una moneda al aire y observar la cara de la moneda que mira hacia arriba al caer.**

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import numpy as np

# Función para lanzar la moneda
def lanzar_moneda():
    return np.random.choice(['CARA', 'SELLO'])

# Inicialización de variables para contar los resultados
resultados = {'CARA': 0, 'SELLO': 0}

# Función para actualizar los resultados y el gráfico en cada fotograma de la animación
def actualizar(i):
    resultado = lanzar_moneda()
    resultados[resultado] += 1
    ejes[0].clear()
    ejes[0].text(0.5, 0.5, resultado, fontsize=50, ha='center', va='center')
    ejes[1].clear()
    ejes[1].bar(resultados.keys(), resultados.values(), color=['blue', 'red'])

# Configuración inicial del gráfico
fig, ejes = plt.subplots(1, 2, figsize=(10, 5))

# Configuración de la animación
ani = animation.FuncAnimation(fig, actualizar, frames=19, interval=500, repeat=False)
print(resultados)
# Muestra la animación en el notebook
HTML(ani.to_html5_video())
# Out:
# {'CARA': 0, 'SELLO': 0}
# <video width="1000" height="500" controls autoplay>
#   <source type="video/mp4" src="...

# %%
# %%R
# # Función para lanzar la moneda
# lanzar_moneda <- function() {
#   sample(c('CARA', 'SELLO'), 1)
# }
#
# # Número de lanzamientos
# n_lanzamientos <- 20
#
# # Inicialización de variables para contar los resultados
# resultados <- c('CARA' = 0, 'SELLO' = 0)
#
# # Realizar los lanzamientos y actualizar los resultados
# for (i in 1:n_lanzamientos) {
#   resultado <- lanzar_moneda()
#   resultados[resultado] <- resultados[resultado] + 1
# }
#
# # Crear un gráfico de barras con los resultados finales
# barplot(
#   resultados,
#   main = 'Resultados de Lanzamientos de Moneda',
#   xlab = 'Cara de la Moneda',
#   ylab = 'Número de Ocurrencias',
#   col = c('blue', 'red'),
#   ylim = c(0, n_lanzamientos)
# )
#
# # Imprimir los resultados
# print(resultados)
# Out:
#  CARA SELLO
#     7    13

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T2"></a>
# ## **2. Experimento Aleatorio - Lanzamiento de un dado (6 caras)**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulación
n = 120000
resultados = np.random.randint(1, 7, size=n)

# Gráfico
plt.hist(resultados, bins=np.arange(0.5, 7.5, 1), rwidth=0.8, color="skyblue", edgecolor="black")
plt.xticks(range(1, 7))
plt.title("Lanzamiento de un dado - Julio Hurtado")
plt.xlabel("Cara")
plt.ylabel("Frecuencia")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter

# Configuración de la animación
n_total = 12000
intervalo = 50  # milisegundos entre frames
frames_guardar = 80  # número de frames en el GIF

# Pre-generamos todos los lanzamientos
np.random.seed(42)  # para reproducibilidad
todos_resultados = np.random.randint(1, 7, size=n_total)

# Configuración de la figura
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_xlim(0.5, 6.5)
ax.set_ylim(0, 450)
ax.set_xticks(range(1, 7))
ax.set_xlabel("Cara del dado")
ax.set_ylabel("Frecuencia")
ax.set_title("Evolución del lanzamiento de un dado\nMartin Marbello")
ax.grid(True, alpha=0.3)

# Inicializar el histograma
n, bins, patches = ax.hist([], bins=np.arange(0.5, 7.5, 1),
                           rwidth=0.8, color="skyblue", edgecolor="black")

# Texto para mostrar el número de lanzamientos
texto_lanzamientos = ax.text(0.02, 0.95, '', transform=ax.transAxes,
                             fontsize=12, verticalalignment='top',
                             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

def update(frame):
    """Actualiza el histograma para cada frame"""
    # Número de lanzamientos para este frame
    n_lanzamientos = int((frame + 1) * n_total / frames_guardar)

    # Obtener los resultados hasta este momento
    resultados_actuales = todos_resultados[:n_lanzamientos]

    # Actualizar el histograma
    ax.clear()
    ax.hist(resultados_actuales, bins=np.arange(0.5, 7.5, 1),
            rwidth=0.8, color="skyblue", edgecolor="black")
    ax.set_xlim(0.5, 6.5)
    ax.set_ylim(0, 5000)
    ax.set_xticks(range(1, 7))
    ax.set_xlabel("Cara del dado")
    ax.set_ylabel("Frecuencia")
    ax.set_title(f"Lanzamiento de un dado - Martin Marbello\n{frame+1}/{frames_guardar}")
    ax.grid(True, alpha=0.3)

    # Mostrar estadísticas
    if n_lanzamientos > 0:
        frecuencias = [np.sum(resultados_actuales == i) for i in range(1, 7)]
        max_freq = max(frecuencias)
        min_freq = min(frecuencias)
        texto = f"Lanzamientos: {n_lanzamientos}\n"
        texto += f"Máx: {max_freq} | Mín: {min_freq}\n"
        texto += f"Rango: {max_freq - min_freq}"
        ax.text(0.02, 0.95, texto, transform=ax.transAxes,
                fontsize=10, verticalalignment='top',
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    return patches

# Crear la animación
anim = FuncAnimation(fig, update, frames=frames_guardar,
                    interval=intervalo, repeat=True)

# Guardar como GIF
anim.save('dado_animacion.gif', writer=PillowWriter(fps=20))
print("✅ GIF guardado como 'dado_animacion.gif'")

# Mostrar la animación (si estás en Jupyter notebook)
from IPython.display import Image
Image(filename='dado_animacion.gif')
# Out:
# ✅ GIF guardado como 'dado_animacion.gif'

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T3"></a>
# ## **3. Experimento: Lanzamiento de una moneda**

# %%
resultados = np.random.choice(["Cara", "Sello"], size=200)

# Count the occurrences of each outcome
counts = np.unique(resultados, return_counts=True)
outcomes = counts[0]
frequencies = counts[1]

# Create a bar plot
plt.bar(outcomes, frequencies, color=["skyblue", "lightcoral"], edgecolor="black")
plt.title("Lanzamiento de una moneda - Martin Marbello")
plt.xlabel("Resultado")
plt.ylabel("Frecuencia")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter

# Configuración de la animación
n_total = 2000
intervalo = 50  # milisegundos entre frames
frames_guardar = 80  # número de frames en el GIF

# Pre-generamos todos los lanzamientos
np.random.seed(42)  # para reproducibilidad
todos_resultados = np.random.choice(["Cara", "Sello"], size=n_total)

# Configuración de la figura
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_ylim(0, 1200)
ax.set_ylabel("Frecuencia")
ax.set_title("Evolución del lanzamiento de una moneda\nHurtado Julio")
ax.grid(True, alpha=0.3, axis='y')

# Colores para Cara y Sello
colores = ["skyblue", "lightcoral"]

# Función para inicializar
def init():
    ax.bar(["Cara", "Sello"], [0, 0], color=colores, edgecolor="black")
    ax.set_xlabel("Resultado")
    ax.set_ylabel("Frecuencia")
    return []

# Función de actualización para cada frame
def update(frame):
    """Actualiza el gráfico de barras para cada frame"""
    # Número de lanzamientos para este frame
    n_lanzamientos = int((frame + 1) * n_total / frames_guardar)

    # Obtener los resultados hasta este momento
    resultados_actuales = todos_resultados[:n_lanzamientos]

    # Limpiar el eje
    ax.clear()

    # Calcular frecuencias
    conteos = {outcome: np.sum(resultados_actuales == outcome) for outcome in ["Cara", "Sello"]}

    # Crear gráfico de barras
    barras = ax.bar(conteos.keys(), conteos.values(),
                    color=colores, edgecolor="black", alpha=0.8)

    # Configurar el gráfico
    ax.set_ylim(0, max(1200, max(conteos.values()) * 1.1))
    ax.set_xlabel("Resultado", fontsize=12)
    ax.set_ylabel("Frecuencia", fontsize=12)
    ax.set_title(f"Lanzamiento de una moneda - Hurtado Julio\nFrame: {frame+1}/{frames_guardar}", fontsize=14)
    ax.grid(True, alpha=0.3, axis='y')

    # Agregar valores sobre las barras
    for i, (outcome, freq) in enumerate(conteos.items()):
        ax.text(i, freq + 10, str(freq), ha='center', va='bottom', fontsize=11, fontweight='bold')

    # Mostrar estadísticas en el gráfico
    if n_lanzamientos > 0:
        diferencia = abs(conteos["Cara"] - conteos["Sello"])
        porcentaje_cara = (conteos["Cara"] / n_lanzamientos) * 100
        porcentaje_sello = (conteos["Sello"] / n_lanzamientos) * 100

        texto = f"Lanzamientos: {n_lanzamientos}\n"
        texto += f"Diferencia: {diferencia}\n"
        texto += f"Cara: {porcentaje_cara:.1f}% | Sello: {porcentaje_sello:.1f}%"

        ax.text(0.02, 0.95, texto, transform=ax.transAxes,
                fontsize=10, verticalalignment='top',
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.9, edgecolor='gray'))

    # Mostrar línea del valor esperado (1000 para 2000 lanzamientos)
    if n_lanzamientos > 0:
        esperado = n_lanzamientos / 2
        ax.axhline(y=esperado, color='green', linestyle='--', linewidth=1.5, alpha=0.7, label=f'Esperado: {esperado:.0f}')
        ax.legend(loc='upper right', fontsize=9)

    return barras

# Crear la animación
print("Generando animación...")
anim = FuncAnimation(fig, update, frames=frames_guardar,
                    init_func=init, interval=intervalo, repeat=True)

# Guardar como GIF
anim.save('moneda_animacion.gif', writer=PillowWriter(fps=20))
print("✅ GIF guardado como 'moneda_animacion.gif'")

# Mostrar estadísticas finales
print("\n📊 Estadísticas finales:")
print(f"Total lanzamientos: {n_total}")
print(f"Cara: {np.sum(todos_resultados == 'Cara')} veces")
print(f"Sello: {np.sum(todos_resultados == 'Sello')} veces")
print(f"Diferencia: {abs(np.sum(todos_resultados == 'Cara') - np.sum(todos_resultados == 'Sello'))}")

# Si estás en Jupyter notebook, puedes mostrar el GIF con:
from IPython.display import Image
Image(filename='moneda_animacion.gif')
# Out:
# Generando animación...
# ✅ GIF guardado como 'moneda_animacion.gif'
#
# 📊 Estadísticas finales:
# Total lanzamientos: 2000
# Cara: 1016 veces
# Sello: 984 veces
# Diferencia: 32

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T4"></a>
# ## **4. Ejemplo 1: Lanzamiento de un dado justo usando R**

# %%
# %%R
#
# # @title **Espacio muestral para el lanzamiento de un dado $$\Omega=\{1,2,3,4,5,6\}$$**
# omega <- 1:6
#
# # Eventos
# A <- c(2, 4, 6)
# B <- c(4, 5, 6)
# C <- c(2, 3, 5)
#
# # a) Unión de A y B
# union_AB <- union(A, B)
# cat("Unión de A y B:", union_AB, "\n")
#
# # b) Intersección de A y B
# interseccion_AB <- intersect(A, B)
# cat("Intersección de A y B:", interseccion_AB, "\n")
#
# # c) Complemento de A
# complemento_A <- setdiff(omega, A)
# cat("Complemento de A:", complemento_A, "\n")
#
# # d) Diferencia de B y C
# diferencia_BC <- setdiff(B, C)
# cat("Diferencia de B y C:", diferencia_BC, "\n")
# Out:
# Unión de A y B: 2 4 6 5
# Intersección de A y B: 4 6
# Complemento de A: 1 3 5
# Diferencia de B y C: 4 6

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T5"></a>
# ## **5. Ejemplo: Preferencias de helado usando R**

# %%
# %%R
#
# # Total de personas
# total_personas <- 100
#
# # Número de personas por preferencia
# n_chocolate <- 60
# n_vainilla <- 50
# n_ambos <- 30
#
# # a) Unión (chocolate o vainilla)
# n_union_CV <- n_chocolate + n_vainilla - n_ambos
# cat("Chocolate o vainilla:", n_union_CV, "\n")
#
# # b) Solo chocolate
# n_solo_chocolate <- n_chocolate - n_ambos
# cat("Solo chocolate:", n_solo_chocolate, "\n")
#
# # c) No prefieren chocolate
# n_no_chocolate <- total_personas - n_chocolate
# cat("No prefieren chocolate:", n_no_chocolate, "\n")
# Out:
# Chocolate o vainilla: 80
# Solo chocolate: 30
# No prefieren chocolate: 40

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T6"></a>
# ## **6. Probabilidad clasica**

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# %%R
#
# # @title **Espacio muestral de un dado**
# # Espacio muestral del dado
# espacio_muestral_dado <- 1:6
# total_resultados_dado <- length(espacio_muestral_dado)
#
# # Probabilidad de obtener un número par
# resultados_par <- c(2, 4, 6)
# resultados_favorables_par <- length(resultados_par)
# prob_par <- resultados_favorables_par / total_resultados_dado
# cat("Probabilidad de obtener un número par:", prob_par, "\n")
#
# # Probabilidad de obtener un número mayor que 4
# resultados_mayor_4 <- c(5, 6)
# resultados_favorables_mayor_4 <- length(resultados_mayor_4)
# prob_mayor_4 <- resultados_favorables_mayor_4 / total_resultados_dado
# cat("Probabilidad de obtener un número mayor que 4:", prob_mayor_4, "\n")
# Out:
# Probabilidad de obtener un número par: 0.5
# Probabilidad de obtener un número mayor que 4: 0.3333333

# %%
import numpy as np

# Espacio muestral del dado
espacio_muestral_dado = [1, 2, 3, 4, 5, 6]
total_resultados_dado = len(espacio_muestral_dado)

# Probabilidad de obtener un número par
resultados_par = [2, 4, 6]
resultados_favorables_par = len(resultados_par)
prob_par = resultados_favorables_par / total_resultados_dado
print(f"Probabilidad de obtener un número par: {prob_par}")

# Probabilidad de obtener un número mayor que 4
resultados_mayor_4 = [5, 6]
resultados_favorables_mayor_4 = len(resultados_mayor_4)
prob_mayor_4 = resultados_favorables_mayor_4 / total_resultados_dado
print(f"Probabilidad de obtener un número mayor que 4: {prob_mayor_4}")
# Out:
# Probabilidad de obtener un número par: 0.5
# Probabilidad de obtener un número mayor que 4: 0.3333333333333333

# %%
# %%R
#
# # @title **Espacio muestral de los digitos**
# espacio_muestral_primo <- 0:9
# total_resultados_primo <- length(espacio_muestral_dado)
#
# # Probabilidad de obtener un número par
# resultados_primo <- c(2, 3, 5, 7)
# resultados_favorables_primo <- length(resultados_primo)
# prob_par <- resultados_favorables_primo / total_resultados_primo
# cat("Probabilidad de obtener un número par:", prob_par, "\n")
# Out:
# Probabilidad de obtener un número par: 0.6666667

# %% [markdown]
# <a name="T7"></a>
# ## **7. Ejemplo 1: Estimación de la probabilidad de obtener cara en una moneda (posiblemente sesgada)**

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# %%R
#
# # Probabilidad verdadera de cara (desconocida para el experimentador)
# prob_verdadera_cara <- 0.6
#
# # Número de lanzamientos en cada etapa
# n_lanzamientos <- c(10, 50, 100, 500, 1000, 5000)
# frecuencias_relativas_cara <- numeric(length(n_lanzamientos))
#
# set.seed(123) # Para reproducibilidad
#
# for (i in 1:length(n_lanzamientos)) {
#   lanzamientos <- rbinom(n_lanzamientos[i], 1, prob_verdadera_cara) # 1 = cara, 0 = cruz
#   frecuencias_relativas_cara[i] <- mean(lanzamientos)
# }
#
# # Visualización de la convergencia
# plot(n_lanzamientos, frecuencias_relativas_cara, type = "b", pch = 16,
#      xlab = "Número de Lanzamientos", ylab = "Frecuencia Relativa de Caras",
#      main = "Probabilidad Frecuentista: Lanzamiento de Moneda")
# abline(h = prob_verdadera_cara, col = "red", lty = 2)

# %%
from matplotlib import pyplot as plt
from matplotlib import animation
import numpy as np

# Parámetros del problema
p_verdadera = 0.5      # Probabilidad de éxito (cara)
epsilon = 0.05         # Margen de error
n_total = 500          # Número total de lanzamientos
intervalo_confianza_inferior = p_verdadera - epsilon
intervalo_confianza_superior = p_verdadera + epsilon

# Parámetros de animación
num_frames = n_total   # Un frame por lanzamiento
interval_ms = 50       # Milisegundos entre frames

# Estadísticas
exitos = 0
frecuencias = []
ensayos = []

# Figura con dos subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
fig.suptitle('Ley de los Grandes Números (Jacob Bernoulli, 1713)',
             fontsize=14, weight='bold')

def actualizar(frame):
    global exitos, frecuencias, ensayos

    # Limpiar ejes
    ax1.clear()
    ax2.clear()

    # Simular un lanzamiento (éxito = cara)
    es_exito = np.random.random() < p_verdadera
    if es_exito:
        exitos += 1

    n = frame + 1  # Número de ensayos hasta ahora
    frecuencia = exitos / n

    # Guardar historial
    frecuencias.append(frecuencia)
    ensayos.append(n)

    # === PRIMER GRÁFICO: Evolución de la frecuencia ===
    ax1.plot(ensayos, frecuencias, 'b-', linewidth=2, label='Frecuencia relativa (k/n)')
    ax1.axhline(y=p_verdadera, color='green', linestyle='-',
                linewidth=2, label=f'p = {p_verdadera} (verdadera)')
    ax1.axhline(y=intervalo_confianza_inferior, color='orange',
                linestyle='--', linewidth=1.5, alpha=0.7)
    ax1.axhline(y=intervalo_confianza_superior, color='orange',
                linestyle='--', linewidth=1.5, alpha=0.7)

    # Rellenar banda de confianza
    ax1.fill_between(ensayos,
                     intervalo_confianza_inferior,
                     intervalo_confianza_superior,
                     alpha=0.2, color='orange',
                     label=f'Banda p ± ε (ε={epsilon})')

    # Punto actual
    ax1.scatter(n, frecuencia, color='red', s=80, zorder=5)

    # Configuración primer gráfico
    ax1.set_xlim(0, n_total)
    ax1.set_ylim(0, 1)
    ax1.set_xlabel('Número de lanzamientos (n)', fontsize=10)
    ax1.set_ylabel('Frecuencia relativa (k/n)', fontsize=10)
    ax1.set_title('Convergencia de la frecuencia relativa', fontsize=11, weight='bold')
    ax1.grid(True, alpha=0.3)
    ax1.legend(loc='upper right', fontsize=8)

    # === SEGUNDO GRÁFICO: Barras de error ===
    error_absoluto = abs(frecuencia - p_verdadera)
    dentro_banda = error_absoluto < epsilon

    # Crear gráfico de barras para el error
    colores_barra = ['green' if dentro_banda else 'red']
    ax2.bar(0, error_absoluto, color=colores_barra[0], alpha=0.7, width=0.6)
    ax2.axhline(y=epsilon, color='orange', linestyle='--',
                linewidth=2, label=f'ε = {epsilon}')

    # Configuración segundo gráfico
    ax2.set_xlim(-0.5, 0.5)
    ax2.set_ylim(0, 1)
    ax2.set_xticks([])
    ax2.set_ylabel('Error absoluto |k/n - p|', fontsize=10)
    ax2.set_title(f'Error: {"DENTRO" if dentro_banda else "FUERA"} de la banda (n={n})',
                  fontsize=11, weight='bold', color=colores_barra[0])
    ax2.grid(True, alpha=0.3, axis='y')
    ax2.legend(loc='upper right', fontsize=9)

    # Añadir texto informativo
    info_texto = f"""
    Lanzamientos: {n}
    Éxitos (caras): {exitos}
    Frecuencia: {frecuencia:.4f}
    Error: {error_absoluto:.4f}
    Teórico: p = {p_verdadera}
    """
    ax2.text(0.05, 0.95, info_texto, transform=ax2.transAxes,
             fontsize=9, verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5),
             family='monospace')

# Crear animación
ani = animation.FuncAnimation(
    fig,
    actualizar,
    frames=num_frames,
    interval=interval_ms,
    repeat=False
)

# Guardar GIF
gif_path = "ley_grandes_numeros_moneda.gif"
ani.save(gif_path, writer='pillow', fps=1000/interval_ms)

plt.close(fig)

print("✅ GIF creado correctamente")
print(f"📁 Ruta: {gif_path}")
print(f"\n🎲 Parámetros de la simulación:")
print(f"   • Probabilidad teórica (p): {p_verdadera}")
print(f"   • Margen de error (ε): {epsilon}")
print(f"   • Total de lanzamientos: {n_total}")
print(f"\n📊 Lo que demuestra el GIF:")
print(f"   • Al principio: grandes fluctuaciones")
print(f"   • A medida que n crece: la frecuencia se acerca a p")
print(f"   • El error |k/n - p| tiende a ser menor que ε")
print(f"\n🎯 Interpretación del Teorema:")
print(f"   lim P(|k/n - p| < ε) = 1  cuando n → ∞")
print(f"   • Para n={n_total}, ya se observa convergencia")
# Out:
# ✅ GIF creado correctamente
# 📁 Ruta: ley_grandes_numeros_moneda.gif
#
# 🎲 Parámetros de la simulación:
#    • Probabilidad teórica (p): 0.5
#    • Margen de error (ε): 0.05
#    • Total de lanzamientos: 500
#
# 📊 Lo que demuestra el GIF:
#    • Al principio: grandes fluctuaciones
#    • A medida que n crece: la frecuencia se acerca a p
#    • El error |k/n - p| tiende a ser menor que ε
#
# 🎯 Interpretación del Teorema:
#    lim P(|k/n - p| < ε) = 1  cuando n → ∞
#    • Para n=500, ya se observa convergencia

# %% [markdown]
# <a name="T8"></a>
# ## **8. Técnicas de Conteo - Formación de Números**

# %% [markdown]
# Problema: ¿Cuántos números de 3 dígitos se pueden formar utilizando los dígitos {1, 2, 3, 4, 5} si:
#
# a) Los dígitos se pueden repetir?
# b) Los dígitos no se pueden repetir?
#
# Solución:
#
# a) Con repetición: Tenemos 5 opciones para el primer dígito, 5 para el segundo y 5 para el tercero (principio de multiplicación y ordenaciones con repetición con m=5 y n=3).
#
# N = 5 × 5 × 5 = 5³ = 125
# b) Sin repetición: Tenemos 5 opciones para el primer dígito, 4 para el segundo y 3 para el tercero (permutaciones sin repetición, P(5, 3)).
#
# N = P(5, 3) = 5! / (5 - 3)! = 120 / 2 = 60

# %%
# %%R
# # a) Con repetición
# m <- 5      # Número de dígitos disponibles
# n <- 3      # Longitud del número
# con_repeticion <- m^n
# cat("Con repetición:", con_repeticion, "\n")
#
# # b) Sin repetición
# sin_repeticion <- factorial(m) / factorial(m - n)
# cat("Sin repetición:", sin_repeticion, "\n")
# Out:
# Con repetición: 125
# Sin repetición: 60

# %%
#Simulacion
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import itertools
import numpy as np
from matplotlib.patches import FancyBboxPatch

def crear_simulacion_gif():
    """
    Crea una animación GIF que simula la formación de números de 3 dígitos.
    """
    digitos = [1, 2, 3, 4, 5]

    # Generamos los números para ambos casos
    numeros_con_rep = list(itertools.product(digitos, repeat=3))
    numeros_sin_rep = list(itertools.permutations(digitos, 3))

    # Configuración de la figura
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
    fig.suptitle('SIMULACIÓN: Números de 3 Dígitos con {1,2,3,4,5}',
                 fontsize=14, fontweight='bold')

    # Configuración de ejes
    ax1.set_title('CASO A: Con Repetición (5³ = 125 números)', fontsize=12)
    ax1.set_xlim(0, 10)
    ax1.set_ylim(0, 10)
    ax1.axis('off')

    ax2.set_title('CASO B: Sin Repetición - P(5,3) = 60 números', fontsize=12)
    ax2.set_xlim(0, 10)
    ax2.set_ylim(0, 10)
    ax2.axis('off')

    # Textos iniciales
    texto1 = ax1.text(5, 5, '', ha='center', va='center', fontsize=30, fontweight='bold')
    texto2 = ax2.text(5, 5, '', ha='center', va='center', fontsize=30, fontweight='bold')

    # Información de conteo
    info1 = ax1.text(5, 2, '', ha='center', va='center', fontsize=14, color='blue')
    info2 = ax2.text(5, 2, '', ha='center', va='center', fontsize=14, color='red')

    # Función de animación
    def animate(frame):
        idx = frame % len(numeros_con_rep)

        # Actualizar caso con repetición
        num_con_rep = numeros_con_rep[idx]
        texto1.set_text(f'{num_con_rep[0]}{num_con_rep[1]}{num_con_rep[2]}')
        info1.set_text(f'Número {idx+1} de {len(numeros_con_rep)}')

        # Actualizar caso sin repetición (mostrar 5 números a la vez)
        idx_sin_rep = idx % len(numeros_sin_rep)
        nums_mostrar = numeros_sin_rep[idx_sin_rep:idx_sin_rep+5]
        if len(nums_mostrar) < 5:
            nums_mostrar.extend(numeros_sin_rep[:5-len(nums_mostrar)])

        texto2.set_text('  '.join([f'{n[0]}{n[1]}{n[2]}' for n in nums_mostrar]))
        info2.set_text(f'Número {idx_sin_rep+1} de {len(numeros_sin_rep)}')

        return [texto1, texto2, info1, info2]

    # Crear animación
    ani = animation.FuncAnimation(fig, animate, frames=len(numeros_con_rep)*2,
                                   interval=200, blit=True)

    # Guardar como GIF
    ani.save('simulacion_conteo.gif', writer='pillow', fps=5, dpi=100)
    print("✅ GIF generado exitosamente: 'simulacion_conteo.gif'")

    plt.show()

if __name__ == "__main__":
    crear_simulacion_gif()
# Out:
# ✅ GIF generado exitosamente: 'simulacion_conteo.gif'

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T9"></a>
# ## **9. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T10"></a>
# ## **10. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T11"></a>
# ## **11. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T12"></a>
# ## **12. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T13"></a>
# ## **13. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T14"></a>
# ## **14. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# ## **15. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T16"></a>
# ## **16. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T17"></a>
# ## **17. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T18"></a>
# ## **18. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T19"></a>
# ## **19. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T20"></a>
# ## **20. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T21"></a>
# ## **21. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T22"></a>
# ## **22. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T23"></a>
# ## **23. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T24"></a>
# ## **24. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T25"></a>
# ## **25. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T26"></a>
# ## **26. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T27"></a>
# ## **27. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T28"></a>
# ## **28. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T29"></a>
# ## **29. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T30"></a>
# ## **30. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# ## **ULTIMO**
# [⬆️ Volver al ULTIMO](#ULTIMO)

# %% [markdown]
# <a name="ULTIMO"></a>

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)
#
# ULTIMO
